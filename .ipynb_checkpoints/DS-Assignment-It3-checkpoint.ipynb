# %% [markdown]
# ##### Instructions
# - Keep the original structure, you may add additional code cells and/or mark-down cells for clarity, legibility and/or structure.
# - Add the required descriptions, explanations, justifications to the mark-down cells.

# %% [markdown]
# # EXAM03: Data Science Group Assignment - Iteration 3
#
# **Group name:** [Enter Group Number]
#
# **Student names & numbers:**
# * Timo Storny - 00099699
# * Jakub Holik - 00099393

# %% [markdown]
# ---
#
# ## 0. Iteration setup

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import numpy as np
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# **Load & Merge dataset(s)**

# %%
iteration2_df = pd.read_csv('iteration2_final.csv', sep=';')
ship_logs_df = pd.read_csv('ship_performance_logs_iter3.csv', sep=',')

df_merged = iteration2_df.merge(ship_logs_df, left_on='Ship_ID', right_on='Ship_ID', how='left')

# %% [markdown]
# ---
#
# ## 1. Business Understanding
#
# **Situation description**
#
# Nebula Brokerage has unanimously decided that they must adopt a machine learning approach rather than a simple benchmark model or decision tree, because their competitors have moved to more advanced technology and Nebula's shareholders are demanding higher margins. Unfortunately the board has identified 2 multi-million galactic credit inefficiencies. The first being the price leakage - the pricing modcel from iteration 1 drastically underprices high-performance ships and overpriced worn-out ones. The second being the safety compliance, however the additional data from tghe Imperial Registry will allow us to handle stolen and smuggler ships for effectively.
#
#
# **Business objective(s)**
#
# *Justify why an AI-driven pipeline (predicting both Galactic Credits and Condition) adds business value.*
#
# **Data mining goal(s)**
#
# In this iteration, we will be creating 2 models. The first will Nebula Brokerage more adequately price their ships, and the second will be used for safety compliance
# **Success criteria**
#
# *Determine the success criteria.*

# %% [markdown]
# ---
#
# ## 2. Data Understanding
#
# **Data exploration (New Features)**
#
# *Show the summary statistics for the newly merged data. Focus your description on the new variables: Lightyears_Traveled and Registration_Status.*

# %%
# CODE CELL: Show basic statistics and information for the final merged dataset
df_merged.describe()
# Out:
#             Ship_ID  Galactic_Credits    Model_Cycle  Reactor_Power  \
# count  3.118770e+05     311877.000000  311877.000000  311877.000000
# mean   7.311490e+09      19259.709757    7511.262879      62.145493
# std    4.381103e+06      15496.937484       9.066350      22.837129
# min    7.301583e+09        501.000000    7400.000000      30.000000
# 25%    7.308127e+09       7900.000000    7508.000000      40.000000
# 50%    7.312617e+09      15898.000000    7513.000000      60.000000
# 75%    7.315246e+09      27900.000000    7517.000000      80.000000
# max    7.317101e+09     777777.000000    7522.000000     120.000000
#
#        Lightyears_Traveled
# count        305913.000000
# mean            105.253101
# std              88.968493
# min               0.000000
# 25%              30.920883
# 50%              86.172002
# 75%             158.102737
# max            1559.606111

# %%
df_merged.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 311877 entries, 0 to 311876
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Ship_ID              311877 non-null  int64
#  1   Galactic_Credits     311877 non-null  int64
#  2   Model_Cycle          311877 non-null  float64
#  3   Ship_Manufacturer    311877 non-null  str
#  4   Sector               311877 non-null  str
#  5   Hull_Integrity       311877 non-null  str
#  6   Reactor_Power        311877 non-null  float64
#  7   Propulsion_Type      311877 non-null  str
#  8   Ship_Class           311877 non-null  str
#  9   Lightyears_Traveled  305913 non-null  float64
#  10  Registration_Status  305913 non-null  str
# dtypes: float64(3), int64(2), str(6)
# memory usage: 26.2 MB

# %%
df_merged['Registration_Status'].value_counts()
# Out:
# Registration_Status
# Imperial Certified    148030
# Refurbished            64546
# Smuggler Logic         37560
# Stolen                 24957
# Scrap                  24939
# Unknown                 5881
# Name: count, dtype: int64

# %% [markdown]
# **Visualizations and patterns**
# *Create visualizations to discover the impact of the new features.

# %%
# CODE CELL: Generate visualizations for the new features
plt.figure(figsize=(12,6))
plt.title('Count plot displaying total amounts per Registration_Status')
sns.countplot(data=df_merged, x='Registration_Status', hue='Hull_Integrity')
# Out:
# <Axes: title={'center': 'Count plot displaying total amounts per Registration_Status'}, xlabel='Registration_Status', ylabel='count'>

# %%
# crosstab = pd.crosstab(df_merged['Registration_Status'], df_merged['Hull_Integrity'], normalize="index") * 100
# sns.heatmap(crosstab, annot=True)

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df_merged, y='Galactic_Credits', x='Lightyears_Traveled', hue='Ship_Class')
# Out:
# <Axes: xlabel='Lightyears_Traveled', ylabel='Galactic_Credits'>

# %% [markdown]
# ## Quality Issues

# %%
logs_length = len(ship_logs_df)
iteration2_data_length = len(iteration2_df)
print("Total ship logs:", logs_length)
print("Total full rows:", iteration2_data_length)
print(f"Difference: {logs_length - iteration2_data_length}")

total_na = df_merged[df_merged['Registration_Status'].isna() | df_merged['Lightyears_Traveled'].isna()]
print(f"Total rows missing either Lightyears_Traveled or Registration_Status: {len(total_na)}")
# Out:
# Total ship logs: 361069
# Total full rows: 311877
# Difference: 49192
# Total rows missing either Lightyears_Traveled or Registration_Status: 5964

# %% [markdown]
# ## Handling outliers

# %%
# sns.boxplot(data=df_merged, x='Galactic_Credits')
df_merged.describe()
sns.boxplot(data=df_merged, x='Galactic_Credits')
# Out:
# <Axes: xlabel='Galactic_Credits'>

# %% [markdown]
# #### Missing values
# With an outer-join we would have 49192 more rows, however majority of which would be without any other data from the columns. 5964 rows that existed in the iteration 2 dataset, have corresponding Lightyears_Traveled or a Registration_Status.

# %% [markdown]
# #### Insights
# From the count plot we see above, we can learn quite a few things. First, besides the Unknown Registration_Status, Imperial Certified and Refurbished have thew lowest count for Critical (Hull_Integrity), whereas the vast majority of the ships that fall under either Smuggler, Stolen or Scrap are in Critical condition. On the other hand, about half of the  ships that are Imperial Certified

# %% [markdown]
# ---
#
# ## 3. Data Preparation
#
# **Cleaning and preprocessing**
#
# *Describe and justify how you resolve your data errors.*

# %% [markdown]
# We decided to simply remove the 5964 rows where there was either Lightyears_Traveled or Registration_Status missing.

# %%
df_merged = df_merged.dropna(subset=['Lightyears_Traveled', 'Registration_Status'])
df_merged['Propulsion_Type'].unique()
# Out:
# <StringArray>
# [      'Ion Drive',      'Solar Sail',   'Graviton Beam',      'Hyperdrive',
#  'Plasma Thruster',   'Nuclear Pulse',   'Plasma Hybrid',      'Antimatter']
# Length: 8, dtype: str

# %% [markdown]
# **Feature encoding**
#
# *Describe how you converted your categorical columns into a format the model can use.*

# %%
df_encoded = pd.get_dummies(df_merged, columns=['Registration_Status'])
# 'Propulsion_Type', 'Ship_Class', 'Ship_Manufacturer', 'Hull_Integrity'
df_encoded.head(1)
# features = df_encoded.drop(columns=['Propulsion_Type'])
features = df_encoded[['Hull_Integrity_Pristine', 'Hull_Integrity_Operational', 'Hull_Integrity_Critical']]
target = df_encoded['Galactic_Credits']

# df_encoded
# print(len(df_encoded), len(target), len(features))

# %%
# filter to show where rows have at least 1 nan
df_encoded[df_encoded.isna().any(axis=1)]
df_encoded.head(1)
# Out:
#       Ship_ID  Galactic_Credits  Model_Cycle                 Sector  \
# 0  7316160254              4950       7505.0  Mon Cala Ocean Worlds
#
#    Reactor_Power  Lightyears_Traveled  Registration_Status_Imperial Certified  \
# 0           40.0           104.554402                                   False
#
#    Registration_Status_Refurbished  Registration_Status_Scrap  \
# 0                            False                      False
#
#    Registration_Status_Smuggler Logic  ...  Ship_Manufacturer_Hondo Systems  \
# 0                                True  ...                            False
#
#    Ship_Manufacturer_Independent Shipwrights  Ship_Manufacturer_Jumpship Corp  \
# 0                                      False                            False
#
#    Ship_Manufacturer_Kuat Drive Yards  Ship_Manufacturer_Mercurian Benz  \
# 0                               False                             False
#
#    Ship_Manufacturer_Nebula Industries  Ship_Manufacturer_Republic Aerospace  \
# 0                                False                                 False
#
#    Hull_Integrity_Critical  Hull_Integrity_Operational  \
# 0                     True                       False
#
#    Hull_Integrity_Pristine
# 0                    False
#
# [1 rows x 43 columns]

# %% [markdown]
# ---
#
# ## 4. Modeling: Task A
#
# **Regression setup**
#
# *Set up a [Linear Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) model to predict `Galactic_Credits`. Make sure to split your data into training and testing sets.*

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.8, random_state=23)

reg = LinearRegression().fit(X_train, y_train)
reg.score(X_train, y_train)
# reg.coef_
# Out:
# 0.30979795172229396

# %% [markdown]
# **Testing and performance (Regression)**
#
# *Calculate the MAE, RMSE and R2 score. Create a plot showing Actual vs. Predicted prices to visually verify model performance.*

# %%
y_pred = reg.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print(mae, mse)

sns.scatterplot(df_)
# CODE CELL: Evaluate the rgression model and plot Actual vs Predicted

# %% [markdown]
# ---
#
# ## 5. Modeling: Task B
#
# **Classification setup**
#
# *Set up a [Decision Tree Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html) to predict `Hull_Integrity`. Split the data into training and testing sets.*

# %%
# CODE CELL: Train-Test split & train the Decision Tree model.

# %% [markdown]
# **Testing and performance (classification)**
#
# *Calculate the Accuracy and plot a confusion matrix. Explain what the matrix tells you about the predictions.*

# %%
# CODE CELL: Evaluate your classification model (check ou tthe metrics, include a confusion matrix)

# %% [markdown]
# ---
#
# ## 6. Evaluation
#
# **Assessment against success criteria**
#
# *Compare your models to the baselines:*
# * *Are thr scores of this regression model better than Iteration 1? Why?*
# * *Are the scores of the decision tree better than your manual rules from Iteration 2? Why?*
#
# **Key findings and limitations**
#
# *What are the final conclusions? Should Nebula Brokerage deploy these models? What are the remaining limitations?*

# %% [markdown]
# Use [pandas' to_csv](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html) to export your cleaned and merged dataset.

# %% [markdown]
# ---
#
# ## 7. Personal Contribution
#
# | Student name | Contribution | Personal lessons learned |
# | :--- | :--- | :--- |
# | Student name 1 | *Contribution description* | *Personal lessons learned this iteration* |
# | Student name 2 | *Contribution description* | *Personal lessons learned this iteration* |
# | Student name 3 | *Contribution description* | *Personal lessons learned this iteration* |
